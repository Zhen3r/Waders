# %%
import rasterio as rio
import matplotlib.pyplot as plt

# %%
with rio.open("./tif/MCD12Q1.006_LC_Type1_doy2005001_aid0001.tif","r")as f:
    print(f.meta)
    a = f.read(1)
# Out:
# {'driver': 'GTiff', 'dtype': 'uint8', 'nodata': 255.0, 'width': 6407, 'height': 6665, 'count': 1, 'crs': CRS.from_epsg(4326), 'transform': Affine(0.004166666666293395, 0.0, 110.35833332344686,
#        0.0, -0.004166666666293395, 45.58333332924974)}

# %%
a==11 or a
# Out:
# array([[10, 10, 10, ...,  4,  4,  4],
#        [10, 10, 10, ...,  4,  4,  4],
#        [10, 10, 10, ...,  4,  4,  4],
#        ...,
#        [17, 17, 17, ..., 17, 17, 17],
#        [17, 17, 17, ..., 17, 17, 17],
#        [17, 17, 17, ..., 17, 17, 17]], dtype=uint8)

# %%
plt.figure(dpi=300)
plt.imshow((a==17) + (a == 11))
